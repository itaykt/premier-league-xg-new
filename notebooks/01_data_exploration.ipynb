# %% [markdown]
# # 01 — Data acquisition & exploration
#
# Use `statsbombpy` to list matches and load events; filter shots and inspect freeze frames.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent if (Path.cwd().name == "notebooks") else Path.cwd()
sys.path.insert(0, str(ROOT))

from src.data_loader import load_matches, load_season_shots, DEFAULT_COMPETITION_ID, DEFAULT_SEASON_ID

matches = load_matches(DEFAULT_COMPETITION_ID, DEFAULT_SEASON_ID)
print(len(matches), "matches")
shots = load_season_shots(DEFAULT_COMPETITION_ID, DEFAULT_SEASON_ID, max_matches=5)
shots.head()
