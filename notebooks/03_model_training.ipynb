# %% [markdown]
# # 03 — Model training
#
# Train logistic regression and XGBoost; compare to baseline features.

# %%
# Prefer: python scripts/train_and_export.py --max-matches 30
print("Run scripts/train_and_export.py from repo root for full pipeline.")
