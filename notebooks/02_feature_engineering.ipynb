# %% [markdown]
# # 02 — Feature engineering
#
# Build the modeling table from raw shot events.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent if (Path.cwd().name == "notebooks") else Path.cwd()
sys.path.insert(0, str(ROOT))

from src.data_loader import load_season_shots, DEFAULT_COMPETITION_ID, DEFAULT_SEASON_ID
from src.features import build_feature_frame, encode_categoricals

shots = load_season_shots(DEFAULT_COMPETITION_ID, DEFAULT_SEASON_ID, max_matches=10)
raw = build_feature_frame(shots)
feats, _ = encode_categoricals(raw)
feats.describe()
