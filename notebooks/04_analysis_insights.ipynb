# %% [markdown]
# # 04 — Evaluation & insights
#
# Calibration plots, player/team aggregates, match narratives.

# %%
import pandas as pd
from pathlib import Path
ROOT = Path.cwd().parent if (Path.cwd().name == "notebooks") else Path.cwd()
df = pd.read_parquet(ROOT / "data/processed/shots_features.parquet")
df.head()
